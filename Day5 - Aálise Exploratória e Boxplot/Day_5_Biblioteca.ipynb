# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# #Coleta de Dados

# %%
dados_2010_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20101.csv?raw=true')
dados_2010_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20102.csv?raw=true')
dados_2011_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20111.csv?raw=true')
dados_2011_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20112.csv?raw=true')
dados_2012_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20121.csv?raw=true')
dados_2012_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20122.csv?raw=true')
dados_2013_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20131.csv?raw=true')
dados_2013_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20132.csv?raw=true')
dados_2014_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20141.csv?raw=true')
dados_2014_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20142.csv?raw=true')
dados_2015_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20151.csv?raw=true')
dados_2015_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20152.csv?raw=true')
dados_2016_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20161.csv?raw=true')
dados_2016_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20162.csv?raw=true')
dados_2017_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20171.csv?raw=true')
dados_2017_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20172.csv?raw=true')
dados_2018_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20181.csv?raw=true')
dados_2018_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20182.csv?raw=true')
dados_2019_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20191.csv?raw=true')
dados_2019_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20192.csv?raw=true')
dados_2020_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20201.csv?raw=true')

# %%
emprestimos = pd.concat([dados_2010_1,dados_2010_2,dados_2011_1,dados_2011_2,dados_2012_1,dados_2012_2,dados_2013_1,dados_2013_2,dados_2014_1,
                                    dados_2014_2,dados_2015_1,dados_2015_2,dados_2016_1,dados_2016_2,dados_2017_1,dados_2017_2,dados_2018_1,dados_2018_2,
                                    dados_2019_1,dados_2019_2,dados_2020_1],ignore_index=True)
emprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# #Verificando duplicatas existentes

# %%
emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# ...

# %% [markdown]
# #Exclusão de duplicatas

# %%
emprestimos = emprestimos.drop_duplicates()

# %%
emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 2336122        2011033079     2016/11/21 02:01:58.488000000  2016/11/10 17:00:12.989000000  2016/12/02 14:21:49.000000000  2.016023e+09        ALUNO DE GRADUAÇÃO        1
# 2336103        2014085936     2016/11/25 19:25:36.215000000  2016/11/10 16:54:52.447000000  2016/12/13 14:30:52.000000000  2.014047e+09        ALUNO DE GRADUAÇÃO        1
# 2336104        2011027960     2016/11/23 17:27:54.642000000  2016/11/10 16:55:17.956000000  2016/11/28 10:32:38.000000000  2.016083e+09        ALUNO DE GRADUAÇÃO        1
# ...

# %%
emprestimos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 8         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 8  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %% [markdown]
# #Importando dados exemplares

# %%
exemplares = pd.read_parquet('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/dados_exemplares.parquet?raw=true')
exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %% [markdown]
# #Unindo os dataframes

# %%
emprestimos_unidos = emprestimos.merge(exemplares)
emprestimos_unidos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# #Quantidade de Empréstimos por Ano
# Houve um decaimento na quantidade de empréstimos por ano.

# %%
emprestimos_unidos['ano'] = pd.to_datetime(emprestimos_unidos['data_emprestimo']).dt.year

# %%
emprestimos_por_ano = emprestimos_unidos.groupby('ano').size()

emprestimos_por_ano.plot(kind='line', marker='o', title='Quantidade de Empréstimos por Ano')

plt.ylabel('Quantidade de Empréstimos')
plt.xlabel('Ano')
plt.grid(True)

plt.show()

# %% [markdown]
# #Dia 2 - Manipulando os Dados

# %%
emprestimos_unidos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
CDU_lista = []
for CDU in emprestimos_unidos['localizacao']:
  if(CDU < 100):
    CDU_lista.append('Generalidades')
  elif(CDU < 200):
    CDU_lista.append('Filosofia e psicologia')
  elif(CDU < 300):
    CDU_lista.append('Religião')
  elif(CDU < 400):
    CDU_lista.append('Ciências sociais')
  elif(CDU < 500):
    CDU_lista.append('Classe vaga')
  elif(CDU < 600):
    CDU_lista.append('Matemática e ciências naturais')
  elif(CDU < 700):
    CDU_lista.append('Ciências aplicadas')
  elif(CDU < 800):
    CDU_lista.append('Belas artes')
  elif(CDU < 900):
    CDU_lista.append('Linguagem')
  else:
    CDU_lista.append('Geografia. Biografia. História.')

emprestimos_unidos['CDU_geral'] = CDU_lista

# %%
emprestimos_unidos.drop(columns=['registro_sistema'],inplace=True)

# %%
emprestimos_unidos['matricula_ou_siape'] = emprestimos_unidos['matricula_ou_siape'].astype('string')

# %%
emprestimos_unidos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# #Dia 3 - Explorando os Dados

# %%
emprestimos_unidos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
emprestimos_unidos['id_emprestimo'].value_counts()
# Out:
# id_emprestimo
# 1775991     3
# 10114792    3
# 1752337     3
# 2595954     3
# 9690168     3
#            ..
# 872007      1
# 871995      1
# 10310064    1
# 1898910     1
# 2989061     1
# Name: count, Length: 2068724, dtype: int64

# %%
emprestimos_unidos.loc[emprestimos_unidos['id_emprestimo']==1775991]
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 1594541        1775991    2010082015  2014/07/27 19:01:41.405000000
# 1594542        1775991    2010082015  2014/07/27 19:01:41.405000000
# 1594543        1775991    2010082015  2014/07/27 19:01:41.405000000
#
#                        data_emprestimo                 data_devolucao  \
# 1594541  2014/07/14 15:35:51.822000000  2014/08/13 18:37:32.000000000
# 1594542  2014/07/14 15:35:51.822000000  2014/08/13 18:37:32.000000000
# 1594543  2014/07/14 15:35:51.822000000  2014/08/13 18:37:32.000000000
#
#         matricula_ou_siape tipo_vinculo_usuario  id_exemplar  \
# 1594541       2011045050.0   ALUNO DE GRADUAÇÃO      1055921
# 1594542       2011045050.0   ALUNO DE GRADUAÇÃO      1055569
# 1594543       2011045050.0   ALUNO DE GRADUAÇÃO      1056359
#
#                    colecao                      biblioteca status_material  \
# 1594541  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# ...

# %% [markdown]
# ##Quantidade de empréstimos realizados:

# %%
emprestimos = len(emprestimos_unidos['id_emprestimo'].drop_duplicates())
emprestimos
# Out:
# 2068724

# %% [markdown]
# ##Exemplares emprestados

# %%
exemplares = len(emprestimos_unidos)
exemplares
# Out:
# 2072522

# %% [markdown]
# ##Exemplares emprestados no ano

# %%
emprestimos_data = pd.DataFrame(emprestimos_unidos['data_emprestimo'].value_counts()).reset_index()
emprestimos_data.columns = ['Data', 'Quantidade']
emprestimos_data['Data'] = pd.to_datetime(emprestimos_data['Data'])
emprestimos_data
# Out:
#                            Data  Quantidade
# 0       2015-08-18 19:11:08.653           3
# 1       2015-06-02 17:56:18.917           3
# 2       2017-04-20 21:07:44.036           3
# 3       2018-02-22 10:45:11.523           3
# 4       2018-11-22 18:28:01.619           3
# ...                         ...         ...
# 2068686 2013-04-29 16:20:45.412           1
# 2068687 2013-03-04 13:54:17.136           1
# 2068688 2012-07-26 10:40:36.158           1
# 2068689 2012-05-25 15:44:07.721           1
# 2068690 2020-03-17 21:22:22.138           1
#
# [2068691 rows x 2 columns]

# %%
emprestimos_por_ano = emprestimos_data.groupby(by=emprestimos_data.Data.dt.year)['Quantidade'].sum()
emprestimos_por_ano.index.name = 'Ano'
emprestimos_por_ano
# Out:
# Ano
# 2010    161394
# 2011    196390
# 2012    221365
# 2013    234749
# 2014    219189
# 2015    213582
# 2016    215900
# 2017    218462
# 2018    194080
# 2019    171801
# 2020     25610
# Name: Quantidade, dtype: int64

# %% [markdown]
# ##Gráfico

# %%
sns.set_theme(style="darkgrid",
              font_scale=1.2,
              rc={"figure.figsize":(15,7)})

# %%
ax = sns.lineplot(data=emprestimos_por_ano.reset_index(),x='Ano',y='Quantidade')
ax.set(xlabel=None,ylabel=None)
ax.tick_params(axis='x', rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))

ax.set_title('Quantidade de exemplares emprestados do SISBI por ano'+'\n',size=20,loc='left',weight='bold')

ax=ax

# %% [markdown]
# ##Quandtidades de empréstimos por mes

# %%
emprestimos_por_mes = emprestimos_data.groupby(by=emprestimos_data.Data.dt.month)['Quantidade'].sum()
emprestimos_por_mes.index.name = 'Mes'
emprestimos_por_mes
# Out:
# Mes
# 1      67514
# 2     210200
# 3     252185
# 4     208725
# 5     202530
# 6     138123
# 7     123790
# 8     232793
# 9     208234
# 10    188410
# 11    164222
# 12     75796
# Name: Quantidade, dtype: int64

# %%
dic_meses = {1:'Jan',2:'Fev',3:'Mar',4:'Abr',
             5:'Mai',6:'Jun',7:'Jul',8:'Ago',
             9:'Set',10:'Out',11:'Nov',12:'Dez'}

# %%
emprestimos_por_mes.index = emprestimos_por_mes.index.map(dic_meses)

# %%
emprestimos_por_mes
# Out:
# Mes
# Jan     67514
# Fev    210200
# Mar    252185
# Abr    208725
# Mai    202530
# Jun    138123
# Jul    123790
# Ago    232793
# Set    208234
# Out    188410
# Nov    164222
# Dez     75796
# Name: Quantidade, dtype: int64

# %% [markdown]
# ##Gráfico por mês

# %%
ax = sns.lineplot(data=emprestimos_por_mes.to_frame(), x=emprestimos_por_mes.to_frame().index, y=emprestimos_por_mes.to_frame().columns[0]) # Use the index for x-axis and the name of the first column for y-axis
ax.set(xlabel=None,ylabel=None)
ax.tick_params(axis='x',rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))

ax.set_title("Quantidade de exemplares emprestados do SISBI por mês"+"\n",size=20,loc='left',weight='bold')
ax.text(s='Período de 2010 a 2020',x=-0.5,y=265000,fontsize=18, ha='left',color='gray')

ax=ax

# %%
emprestimos_data.Data
# Out:
# 0         2015-08-18 19:11:08.653
# 1         2015-06-02 17:56:18.917
# 2         2017-04-20 21:07:44.036
# 3         2018-02-22 10:45:11.523
# 4         2018-11-22 18:28:01.619
#                     ...
# 2068686   2013-04-29 16:20:45.412
# 2068687   2013-03-04 13:54:17.136
# 2068688   2012-07-26 10:40:36.158
# 2068689   2012-05-25 15:44:07.721
# 2068690   2020-03-17 21:22:22.138
# Name: Data, Length: 2068691, dtype: datetime64[ns]

# %%
emprestimos_por_hora = emprestimos_data.groupby(by=emprestimos_data.Data.dt.hour)['Quantidade'].sum()
emprestimos_por_hora.index.name = 'Horas'
emprestimos_por_hora = emprestimos_por_hora.reset_index()
emprestimos_por_hora
# Out:
#     Horas  Quantidade
# 0       0          17
# 1       6          14
# 2       7       18777
# 3       8      103416
# 4       9      131273
# 5      10      185839
# 6      11      180048
# 7      12      148754
# 8      13      126987
# 9      14      150876
# 10     15      166672
# 11     16      210655
# 12     17      185340
# 13     18      182520
# 14     19      102129
# 15     20      127716
# 16     21       51191
# 17     22         247
# 18     23          51

# %%
emprestimos_por_hora = emprestimos_por_hora.sort_values(ascending=True,by='Quantidade')

# %%
ax = sns.barplot(data=emprestimos_por_hora,y='Quantidade',x='Horas',
                 palette='Blues',hue='Quantidade',dodge=False)
plt.legend([],[], frameon=False)

ax.set(xlabel='Horário',ylabel=None)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))
ax.set_title("Quantidade de exemplares emprestados do SISBI por faixa horária"+"\n",size=20,loc='left',weight='bold')
ax.text(s='Período de 2010 a 2020',x=-0.5,y=225000,fontsize=18, ha='left',color='gray')
ax=ax

# %% [markdown]
# ##Entre 10h e 16h são os horários com os maiores números de empréstimos.

# %% [markdown]
# #Dia 4 - Análise Exploratória

# %%
emprestimos_unidos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ##Transformando o dado para o tipo data

# %%
emprestimos_unidos['data_emprestimo'] = pd.to_datetime(emprestimos_unidos['data_emprestimo'])

# %%
emprestimos_unidos.tipo_vinculo_usuario.unique()
# Out:
# array(['ALUNO DE GRADUAÇÃO', 'ALUNO DE PÓS-GRADUAÇÃO', 'DOCENTE',
#        'DOCENTE EXTERNO', 'SERVIDOR TÉCNICO-ADMINISTRATIVO',
#        'ALUNO MÉDIO/TÉCNICO', 'USUÁRIO EXTERNO', 'OUTROS'], dtype=object)

# %%
emprestimos_unidos.biblioteca.unique()
# Out:
# array(['Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Prof. Horácio Nicolas Solimo - \xad Engenharia Química - EQ - CT',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
#        'Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - \xadCT',
# ...

# %%
emprestimos_unidos.CDU_geral.unique()
# Out:
# array(['Ciências aplicadas', 'Linguagem', 'Ciências sociais',
#        'Geografia. Biografia. História.',
#        'Matemática e ciências naturais', 'Religião', 'Generalidades',
#        'Filosofia e psicologia', 'Belas artes'], dtype=object)

# %% [markdown]
# ##Crianmdo função para criar taberla de frequência

# %%
def tabela_de_frequencia(var):
  dataframe = pd.DataFrame(emprestimos_unidos[var].value_counts())
  dataframe.columns = ['Quantidade']
  dataframe['Percentual'] = round((dataframe.Quantidade / dataframe.Quantidade.sum())*100,2)
  return dataframe

# %% [markdown]
# ##Quantidade e percentual do CDU geral

# %%
tabela_de_frequencia('CDU_geral')
# Out:
#                                  Quantidade  Percentual
# CDU_geral
# Ciências aplicadas                  1425473       68.78
# Ciências sociais                     369536       17.83
# Matemática e ciências naturais        68744        3.32
# Generalidades                         62521        3.02
# Religião                              62295        3.01
# Filosofia e psicologia                60563        2.92
# Geografia. Biografia. História.        7989        0.39
# Belas artes                            7911        0.38
# Linguagem                              7490        0.36

# %% [markdown]
# ##Quantidade e percentual de cada tipo de coleção

# %%
tabela_de_frequencia('colecao')
# Out:
#                                        Quantidade  Percentual
# colecao
# Acervo Circulante                         2053120       99.06
# Multimeios                                   7954        0.38
# Monografias                                  4021        0.19
# Dissertações                                 2406        0.12
# Obras de Referência                          1954        0.09
# Publicações de Autores do RN                  866        0.04
# Publicações da UFRN                           764        0.04
# Teses                                         714        0.03
# Folhetos                                      271        0.01
# Necessidades Educacionais Específicas         130        0.01
# Trabalho Acadêmico                            115        0.01
# Eventos                                       101        0.00
# Coleção Mossoroense                            44        0.00
# Coleção Zila Mamede                            30        0.00
# ...

# %% [markdown]
# ##Tabela de frequência dos alunos de cada vínculo.

# %%
tabela_de_frequencia('tipo_vinculo_usuario')
# Out:
#                                  Quantidade  Percentual
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1612324       77.80
# ALUNO DE PÓS-GRADUAÇÃO               302541       14.60
# DOCENTE                               70981        3.42
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32184        1.55
# ALUNO MÉDIO/TÉCNICO                   28029        1.35
# DOCENTE EXTERNO                       23949        1.16
# USUÁRIO EXTERNO                        2509        0.12
# OUTROS                                    5        0.00

# %% [markdown]
# ##Quantidade e percentual das bibliotecas

# %%
tabela_de_frequencia('biblioteca')
# Out:
#                                                     Quantidade  Percentual
# biblioteca
# Biblioteca Central Zila Mamede                         1426122       68.81
# Biblioteca Setorial do Centro Ciências da Saúde...      118614        5.72
# Biblioteca Setorial da Faculdade de Ciências da...       77609        3.74
# Biblioteca Setorial Prof. Alberto Moreira Campo...       66447        3.21
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       61478        2.97
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       46040        2.22
# Biblioteca Setorial do Centro de Ciências Human...       40744        1.97
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32097        1.55
# Biblioteca Setorial Profª. Maria José Mamede Ga...       29089        1.40
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       27219        1.31
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26923        1.30
# ...

# %% [markdown]
# ##Dia 5 -Analise exploratória de dados e Bloxplot

# %%
emprestimos_unidos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#           data_emprestimo                 data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721  2010/01/05 16:26:12.662000000       2008023265.0
# 1 2010-03-01 12:40:56.212  2010/04/30 14:42:35.366000000       2009121584.0
# 2 2010-01-04 07:44:10.750  2010/01/12 07:34:13.934000000       2008023265.0
# 3 2010-02-11 11:16:30.335  2010/03/04 08:54:32.262000000       2008050352.0
# 4 2010-03-04 13:36:26.599  2010/03/31 18:04:29.669000000        200722565.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ##Usos dos Alunos de Graduação

# %%
alunos_graduacao = emprestimos_unidos.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
alunos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        1600155
# Multimeios                                  4652
# Monografias                                 3572
# Dissertações                                1152
# Obras de Referência                         1047
# Publicações de Autores do RN                 595
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: count, dtype: int64

# %% [markdown]
# ##Criação de tabela com a quantidade por mês

# %%
alunos_graduacao_acervo_circulante = alunos_graduacao.query('colecao == "Acervo Circulante"')
alunos_graduacao_acervo_circulante = pd.DataFrame(alunos_graduacao_acervo_circulante)
alunos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_graduacao_acervo_circulante['data_emprestimo'])
alunos_graduacao_acervo_circulante['Ano'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_graduacao_acervo_circulante['Mes'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.loc[:,['Ano','Mes']]
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.value_counts().to_frame('Quantidade').reset_index()
alunos_graduacao_acervo_circulante
# Out:
#       Ano  Mes  Quantidade
# 0    2012    3       22797
# 1    2015    3       22483
# 2    2013    4       21853
# 3    2017    3       21735
# 4    2016    3       21692
# ..    ...  ...         ...
# 118  2016    1        2670
# 119  2019    1        2276
# 120  2019   12        1980
# 121  2020    1        1781
# 122  2011    1         809
#
# [123 rows x 3 columns]

# %% [markdown]
# ##Boxplot

# %%
def gerar_box_plot(dataset,x,y,titulo,subtitulo):

  sns.set_theme(style="darkgrid", palette='Blues',font_scale=1.3)
  plt.figure(figsize=(16,10))

  ax = sns.boxplot(y= y, x= x, data= dataset,color='#4171EF')
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))

  plt.ylim(0,max(dataset[y])*1.1)
  plt.xlabel(None)
  plt.ylabel(None)

  ax.set_title(titulo+"\n",size=20,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')

# %%
gerar_box_plot(alunos_graduacao_acervo_circulante,'Ano','Quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de graduação no acervo circulante')

# %% [markdown]
# ##Usos dos Alunos de pós graduação

# %%
alunos_pos_graduacao = emprestimos_unidos.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
alunos_pos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        299201
# Dissertações                                934
# Obras de Referência                         700
# Multimeios                                  559
# Teses                                       367
# Monografias                                 278
# Publicações de Autores do RN                204
# Publicações da UFRN                         121
# Folhetos                                     60
# Necessidades Educacionais Específicas        30
# Eventos                                      26
# Coleção Mossoroense                          23
# Trabalho Acadêmico                           23
# Coleção Zila Mamede                          11
# Literatura de Cordel                          4
# Name: count, dtype: int64

# %% [markdown]
# ##Tabela com quantidade por mes dos alunos da pós graduação

# %%
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao.query('colecao == "Acervo Circulante"')
alunos_pos_graduacao_acervo_circulante = pd.DataFrame(alunos_pos_graduacao_acervo_circulante)
alunos_pos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_pos_graduacao_acervo_circulante['data_emprestimo'])
alunos_pos_graduacao_acervo_circulante['Ano'] = alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_pos_graduacao_acervo_circulante['Mes'] = alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao_acervo_circulante.loc[:,['Ano','Mes']]
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao_acervo_circulante.value_counts().to_frame('Quantidade').reset_index()
alunos_pos_graduacao_acervo_circulante
# Out:
#       Ano  Mes  Quantidade
# 0    2015    3        3927
# 1    2017    8        3837
# 2    2017    3        3722
# 3    2016    3        3711
# 4    2016    8        3662
# ..    ...  ...         ...
# 119  2020    1        1143
# 120  2010    1        1105
# 121  2019   12        1069
# 122  2011    1         465
# 123  2020    6           2
#
# [124 rows x 3 columns]

# %% [markdown]
# ##Empréstimos mensais feitos pelos alunos de pós graduação

# %%
gerar_box_plot(alunos_pos_graduacao_acervo_circulante,'Ano','Quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de pós graduação no acervo')

# %% [markdown]
# ##De 2010 até 2013 houve um crescimento no uso pelos alunos de pós-graduação, decaindo após esse período, aumetou um pouco em 2017, mas logo após houve uma queda nos aos posteriores.
