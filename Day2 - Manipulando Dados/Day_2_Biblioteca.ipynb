# %%
*from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

# %% [markdown]
# #Coleta de Dados

# %%
dados_2010_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20101.csv?raw=true')
dados_2010_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20102.csv?raw=true')
dados_2011_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20111.csv?raw=true')
dados_2011_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20112.csv?raw=true')
dados_2012_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20121.csv?raw=true')
dados_2012_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20122.csv?raw=true')
dados_2013_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20131.csv?raw=true')
dados_2013_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20132.csv?raw=true')
dados_2014_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20141.csv?raw=true')
dados_2014_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20142.csv?raw=true')
dados_2015_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20151.csv?raw=true')
dados_2015_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20152.csv?raw=true')
dados_2016_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20161.csv?raw=true')
dados_2016_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20162.csv?raw=true')
dados_2017_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20171.csv?raw=true')
dados_2017_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20172.csv?raw=true')
dados_2018_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20181.csv?raw=true')
dados_2018_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20182.csv?raw=true')
dados_2019_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20191.csv?raw=true')
dados_2019_2 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20192.csv?raw=true')
dados_2020_1 = pd.read_csv('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/emprestimos-20201.csv?raw=true')

# %%
emprestimos = pd.concat([dados_2010_1,dados_2010_2,dados_2011_1,dados_2011_2,dados_2012_1,dados_2012_2,dados_2013_1,dados_2013_2,dados_2014_1,
                                    dados_2014_2,dados_2015_1,dados_2015_2,dados_2016_1,dados_2016_2,dados_2017_1,dados_2017_2,dados_2018_1,dados_2018_2,
                                    dados_2019_1,dados_2019_2,dados_2020_1],ignore_index=True)
emprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# #Verificando duplicatas existentes

# %%
emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# ...

# %% [markdown]
# #Exclusão de duplicatas

# %%
emprestimos = emprestimos.drop_duplicates()

# %%
emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 2336122        2011033079     2016/11/21 02:01:58.488000000  2016/11/10 17:00:12.989000000  2016/12/02 14:21:49.000000000  2.016023e+09        ALUNO DE GRADUAÇÃO        1
# 2336103        2014085936     2016/11/25 19:25:36.215000000  2016/11/10 16:54:52.447000000  2016/12/13 14:30:52.000000000  2.014047e+09        ALUNO DE GRADUAÇÃO        1
# 2336104        2011027960     2016/11/23 17:27:54.642000000  2016/11/10 16:55:17.956000000  2016/11/28 10:32:38.000000000  2.016083e+09        ALUNO DE GRADUAÇÃO        1
# ...

# %%
emprestimos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 8         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 8  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %% [markdown]
# #Importando dados exemplares

# %%
exemplares = pd.read_parquet('https://github.com/Lalset/Alura-7DaysToCode/blob/main/Day1%20-%20Importa%C3%A7%C3%A3o%20de%20dados/emprestimos/dados_exemplares.parquet?raw=true')
exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %% [markdown]
# #Unindo os dataframes

# %%
emprestimos_unidos = emprestimos.merge(exemplares)
emprestimos_unidos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# #Quantidade de Empréstimos por Ano
# Houve um decaimento na quantidade de empréstimos por ano.

# %%
emprestimos_unidos['ano'] = pd.to_datetime(emprestimos_unidos['data_emprestimo']).dt.year

# %%
emprestimos_por_ano = emprestimos_unidos.groupby('ano').size()

emprestimos_por_ano.plot(kind='line', marker='o', title='Quantidade de Empréstimos por Ano')

plt.ylabel('Quantidade de Empréstimos')
plt.xlabel('Ano')
plt.grid(True)

plt.show()

# %% [markdown]
# #Dia 2 - Manipulando os Dados

# %%
emprestimos_unidos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
CDU_lista = []
for CDU in emprestimos_unidos['localizacao']:
  if(CDU < 100):
    CDU_lista.append('Generalidades')
  elif(CDU < 200):
    CDU_lista.append('Filosofia e psicologia')
  elif(CDU < 300):
    CDU_lista.append('Religião')
  elif(CDU < 400):
    CDU_lista.append('Ciências sociais')
  elif(CDU < 500):
    CDU_lista.append('Classe vaga')
  elif(CDU < 600):
    CDU_lista.append('Matemática e ciências naturais')
  elif(CDU < 700):
    CDU_lista.append('Ciências aplicadas')
  elif(CDU < 800):
    CDU_lista.append('Belas artes')
  elif(CDU < 900):
    CDU_lista.append('Linguagem')
  else:
    CDU_lista.append('Geografia. Biografia. História.')

emprestimos_unidos['CDU_geral'] = CDU_lista

# %%
emprestimos_unidos.drop(columns=['registro_sistema'],inplace=True)

# %%
emprestimos_unidos['matricula_ou_siape'] = emprestimos_unidos['matricula_ou_siape'].astype('string')

# %%
emprestimos_unidos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...
